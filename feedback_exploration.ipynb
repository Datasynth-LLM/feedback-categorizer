# %% [markdown]
# # 🧠 AI Feedback Categorizer with Hugging Face Transformers
# This notebook analyzes user feedback using zero-shot classification, sentiment analysis, and keyword extraction.

# %% [markdown]
# ## 📦 Step 1: Install Dependencies

# %%
# !pip install pandas streamlit scikit-learn matplotlib seaborn transformers torch
# Out:
# Requirement already satisfied: pandas in c:\users\avish\appdata\roaming\python\python313\site-packages (2.2.3)
# Requirement already satisfied: streamlit in c:\users\avish\appdata\roaming\python\python313\site-packages (1.46.1)
# Requirement already satisfied: scikit-learn in c:\users\avish\appdata\roaming\python\python313\site-packages (1.7.0)
# Requirement already satisfied: matplotlib in c:\users\avish\appdata\roaming\python\python313\site-packages (3.10.3)
# Requirement already satisfied: seaborn in c:\users\avish\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: transformers in c:\users\avish\anaconda3\lib\site-packages (4.53.0)
# Requirement already satisfied: torch in c:\users\avish\appdata\roaming\python\python313\site-packages (2.7.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\avish\appdata\roaming\python\python313\site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\avish\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\avish\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\avish\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\avish\appdata\roaming\python\python313\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\avish\appdata\roaming\python\python313\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\avish\appdata\roaming\python\python313\site-packages (from streamlit) (6.1.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\avish\appdata\roaming\python\python313\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: packaging<26,>=20 in c:\users\avish\appdata\roaming\python\python313\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\avish\appdata\roaming\python\python313\site-packages (from streamlit) (11.2.1)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\avish\appdata\roaming\python\python313\site-packages (from streamlit) (6.31.1)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\avish\appdata\roaming\python\python313\site-packages (from streamlit) (20.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\avish\appdata\roaming\python\python313\site-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\avish\appdata\roaming\python\python313\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\avish\appdata\roaming\python\python313\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\avish\appdata\roaming\python\python313\site-packages (from streamlit) (4.14.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\avish\appdata\roaming\python\python313\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\avish\appdata\roaming\python\python313\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\avish\appdata\roaming\python\python313\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\avish\appdata\roaming\python\python313\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\avish\appdata\roaming\python\python313\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\avish\appdata\roaming\python\python313\site-packages (from altair<6,>=4.0->streamlit) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\avish\appdata\roaming\python\python313\site-packages (from altair<6,>=4.0->streamlit) (1.44.0)
# Requirement already satisfied: colorama in c:\users\avish\appdata\roaming\python\python313\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\avish\appdata\roaming\python\python313\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\avish\appdata\roaming\python\python313\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\avish\appdata\roaming\python\python313\site-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\avish\appdata\roaming\python\python313\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\avish\appdata\roaming\python\python313\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\avish\appdata\roaming\python\python313\site-packages (from requests<3,>=2.27->streamlit) (2025.6.15)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\avish\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\avish\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\avish\appdata\roaming\python\python313\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\avish\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\avish\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\avish\appdata\roaming\python\python313\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\avish\appdata\roaming\python\python313\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\avish\appdata\roaming\python\python313\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: filelock in c:\users\avish\appdata\roaming\python\python313\site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\users\avish\anaconda3\lib\site-packages (from transformers) (0.33.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\avish\appdata\roaming\python\python313\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\avish\anaconda3\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\avish\anaconda3\lib\site-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\avish\anaconda3\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\avish\appdata\roaming\python\python313\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\avish\appdata\roaming\python\python313\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.5.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\avish\appdata\roaming\python\python313\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\avish\appdata\roaming\python\python313\site-packages (from torch) (3.5)
# Requirement already satisfied: setuptools in c:\users\avish\appdata\roaming\python\python313\site-packages (from torch) (80.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\avish\appdata\roaming\python\python313\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\avish\appdata\roaming\python\python313\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\avish\appdata\roaming\python\python313\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\avish\appdata\roaming\python\python313\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\avish\appdata\roaming\python\python313\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.25.1)
# Requirement already satisfied: six>=1.5 in c:\users\avish\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\avish\appdata\roaming\python\python313\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# 'DOSKEY' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## 🧪 Step 2: Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
from transformers import pipeline
import IPython.display as display

# %% [markdown]
# ## 🗃️ Step 3: Load Feedback Data

# %%
data = [
    {"feedback": "The app crashes every time I try to upload a photo.", "source": "Google Play", "timestamp": "2025-06-01"},
    {"feedback": "Love the new dark mode feature!", "source": "App Store", "timestamp": "2025-06-02"},
    {"feedback": "Can you add support for multiple accounts?", "source": "Email", "timestamp": "2025-06-03"},
    {"feedback": "Customer support was very helpful.", "source": "Trustpilot", "timestamp": "2025-06-04"},
    {"feedback": "The login process is too slow.", "source": "Google Play", "timestamp": "2025-06-05"},
]
df = pd.DataFrame(data)
df.head()
# Out:
#                                             feedback       source   timestamp
# 0  The app crashes every time I try to upload a p...  Google Play  2025-06-01
# 1                    Love the new dark mode feature!    App Store  2025-06-02
# 2         Can you add support for multiple accounts?        Email  2025-06-03
# 3                 Customer support was very helpful.   Trustpilot  2025-06-04
# 4                     The login process is too slow.  Google Play  2025-06-05

# %% [markdown]
# ## 🤗 Step 4: Load Hugging Face Pipelines

# %%
# Load Transformers
sentiment_analyzer = pipeline(
    "sentiment-analysis",
    model="distilbert/distilbert-base-uncased-finetuned-sst-2-english",
    device=0  # 0 means first GPU; use -1 for CPU
)
# Out:
# Device set to use cpu

# %% [markdown]
# ## 🧠 Step 5: Classify Categories, Analyze Sentiment, and Determine Urgency

# %%
# Define categories
categories = ["Bug", "Feature Request", "Complaint", "Compliment", "General"]

def classify_and_analyze(feedback):
    class_result = classifier(feedback, categories, multi_label=True)
    assigned = [label for label, score in zip(class_result['labels'], class_result['scores']) if score > 0.5]
    if not assigned:
        assigned = ["General"]
    sentiment_result = sentiment_analyzer(feedback)[0]
    sentiment = sentiment_result['label']
    if "Bug" in assigned or "Complaint" in assigned:
        urgency = "High"
    elif "Feature Request" in assigned:
        urgency = "Medium"
    else:
        urgency = "Low"
    return pd.Series([assigned, sentiment, urgency])

df[['categories', 'sentiment', 'urgency']] = df['feedback'].apply(classify_and_analyze)
df
# Out:
#                                             feedback       source   timestamp  \
# 0  The app crashes every time I try to upload a p...  Google Play  2025-06-01
# 1                    Love the new dark mode feature!    App Store  2025-06-02
# 2         Can you add support for multiple accounts?        Email  2025-06-03
# 3                 Customer support was very helpful.   Trustpilot  2025-06-04
# 4                     The login process is too slow.  Google Play  2025-06-05
#
#                      categories sentiment urgency
# 0              [Complaint, Bug]  NEGATIVE    High
# 1                  [Compliment]  POSITIVE     Low
# 2  [Feature Request, Complaint]  NEGATIVE    High
# 3                  [Compliment]  POSITIVE     Low
# 4     [Complaint, Bug, General]  NEGATIVE    High

# %% [markdown]
# ## 🗝️ Step 6: Extract Top Keywords

# %%
vectorizer = CountVectorizer(stop_words='english', max_features=10)
X = vectorizer.fit_transform(df['feedback'])
keywords = vectorizer.get_feature_names_out().tolist()

display.display(display.Markdown("### 🔑 Top Keywords\n" + "\n".join([f"- {kw}" for kw in keywords])))
# Out:
# ### 🔑 Top Keywords
# - accounts
# - add
# - app
# - crashes
# - customer
# - dark
# - feature
# - login
# - love
# - support

# %% [markdown]
# ## 📊 Step 7: Visualize Category Distribution

# %%
all_categories = [cat for sublist in df['categories'] for cat in sublist]
cat_df = pd.DataFrame({'category': all_categories})

plt.figure(figsize=(6,4))
sns.countplot(y='category', data=cat_df, order=cat_df['category'].value_counts().index)
plt.title("Feedback Category Distribution")
plt.show()

# %% [markdown]
# ## 💾 Step 8: Save the Processed Data (Optional)

# %%
df.to_csv("processed_feedback.csv", index=False)
print("Processed data saved as processed_feedback.csv")
# Out:
# Processed data saved as processed_feedback.csv

# %% [markdown]
# ## 🔍 Step 9: Display Final Processed Feedback

# %%
for i, row in df.iterrows():
    display.display(display.Markdown(f"**{row['feedback']}**"))
    display.display(display.Markdown(f"- **Categories**: {', '.join(row['categories'])}"))
    display.display(display.Markdown(f"- **Sentiment**: {row['sentiment']} | **Urgency**: {row['urgency']}"))
    display.display(display.Markdown("---"))
# Out:
# **The app crashes every time I try to upload a photo.**
# - **Categories**: Complaint, Bug
# - **Sentiment**: NEGATIVE | **Urgency**: High
# ---
# **Love the new dark mode feature!**
# - **Categories**: Compliment
# - **Sentiment**: POSITIVE | **Urgency**: Low
# ---
# **Can you add support for multiple accounts?**
# - **Categories**: Feature Request, Complaint
# - **Sentiment**: NEGATIVE | **Urgency**: High
# ---
# **Customer support was very helpful.**
# - **Categories**: Compliment
# - **Sentiment**: POSITIVE | **Urgency**: Low
# ---
# **The login process is too slow.**
# - **Categories**: Complaint, Bug, General
# - **Sentiment**: NEGATIVE | **Urgency**: High
# ---
